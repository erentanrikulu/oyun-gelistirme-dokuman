# %%
df= pd.read_csv("C:/Users/eren/Desktop/yeni veriler/data/stemmed_sentences.csv")

# %%
df
# Out:
#      oliv jame cook oliv jame cook prefac prefac prefac prefac alway love silent hill seri q uit easili one main contributor toward extend admir develop
# 0     fi rst play game fourteen continu come back fr...
# 1     reason chose write game silent hill f avourit ...
# 2     lot content document cours prior knowl ge game...
# 3     two main compel object develop allow bleed doc...
# 4      fir script thank print would far direct f assign
# ...                                                 ...
# 1001  start level player spend adventur rememb true ...
# 1002  player start blank slate equival third level c...
# 1003  player level possibl ad charact class previou ...
# 1004           rememb abil pertain class cours adventur
# 1005  abil cast spell beyond current level wish spel...
#
# [1006 rows x 1 columns]

# %%
df.columns = ["0"]

# NaN değerleri ve boş stringleri temizle
df = df.dropna()
df = df[df["0"].str.strip() != ""]

# Temizlenmiş ilk 5 cümleyi göster
print(df.head())
# Out:
#                                                    0
# 0  fi rst play game fourteen continu come back fr...
# 1  reason chose write game silent hill f avourit ...
# 2  lot content document cours prior knowl ge game...
# 3  two main compel object develop allow bleed doc...
# 4   fir script thank print would far direct f assign

# %%
text = ' '.join(df['0'].astype(str).tolist())  # Tüm yorumları tek bir metin haline getir
sentences = sent_tokenize(text)  # Metni cümlelere ayır

# %%
# Stopwords listesini almak
stop_words = set(stopwords.words('english'))

# %%
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk.tokenize import word_tokenize

# Lemmatizer ve Stemmer nesnelerini oluştur
lemmatizer = WordNetLemmatizer()
stemmer = PorterStemmer()
# Kelimeleri tokenleştirip, lemmatize etme ve stemleme
def preprocess_sentence(sentence):
    tokens = word_tokenize(sentence)
    filtered_tokens = [token.lower() for token in tokens if token.isalpha() and token.lower() not in stop_words]
    lemmatized_tokens = [lemmatizer.lemmatize(token) for token in filtered_tokens]
    stemmed_tokens = [stemmer.stem(token) for token in filtered_tokens]
    return lemmatized_tokens, stemmed_tokens

# Kullanım örneği
tokenized_corpus_lemmatized = []
tokenized_corpus_stemmed = []

for sentence in sentences:
    lemmatized_tokens, stemmed_tokens = preprocess_sentence(sentence)
    tokenized_corpus_lemmatized.append(lemmatized_tokens)
    tokenized_corpus_stemmed.append(stemmed_tokens)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Ön işlenmiş token listelerini tekrar metne çeviriyoruz
lemmatized_texts = [' '.join(tokens) for tokens in tokenized_corpus_lemmatized]

lemmatized_texts[:3]
# Out:
# ['fi rst play game fourteen continu come back franchis year af ter year reason chose write game silent hill f avourit game time academ reason invest time research game far beyond previou research lot content document cours prior knowl ge game good proport inform discov projec allow understand develop increas complex two main compel object develop allow bleed docum ent creat origin design document realis fir script thank print would far direct f assign second main theme silent hill compos origin design document conceiv case provid track cd nli authent part origin document revers engin orig inal design document publish onlin imagin would need translat deciph japanes text hope enjoy document oliv cook oliv jame cook content game concept introduct background descript key featur genr platform concept art game mechan core game play game flow charact monster game play element weapon properti game physic statist artifici intellig player control interfac flowchart function requir mock screen art video overal goal art art anim cinemat sound music overal goal sound effect music stori stori overview multipl end level overview locat overview puzzl market analysi target market top perform featur comparison bibliographi oliv jame cook game concept introduct silent hill rd person experi playstat consol protagonist jame sunderland drawn silent hill receiv letter dead wife mari ask meet background silent hill continu franch ise similar feel first game entir new technic method implement lthough game use brand new custom engin mani core concept playstat ion predecessor transpos new engin code reason behind prev iou success silent hill engin allow u creat atmospher truli uniqu franchis mani previou team team silent wo rking project except previou director keiichiro toyama descript silent hill like first game place play er floor town lot question answer player job unravel mysteri happen attract protagonist town killin g lot monster avoid mani fight possibl thing avoid p uzzl horrifi truth game offer circumst avatar ar rival oliv jame cook key featur silent hill silent hill allow player explor origin game locat reveal new disturb area compel new stori silent hill featur brand new stori set silent hill univers brand new charact puzzl monster graphic new graphic real life cg movi silent hill realli immers player game creat natur charact breath take environ game realli push high cinemat qualiti game play cut scene dynam camera angl silent hill use period fix camera angl intensifi game play similar first game add cinemat ic approach game take sound game contain complet new soundtrack compos akira yamaoka creat soundtrack first game game also use technolog creat immers sound difficulti difficulti silent hill set categori riddl level enemi level set level respect individu use tier method genr silent hill like predecessor fall neatli mewher surviv horror psycholog horror though unlik previou ga psycholog horror silent hill appar due stori hav ing direct approach explicit subject matter oliv jame cook platform target platform playstat sure possibl xbox pc port depend game success playstat w ill primari platform concept art oliv jame cook oliv jame cook oliv jame cook oliv jame cook oliv jame cook game mechan core game play core game play silent hill mix fight monster solv puzzl serv progress g ame fight fight silent hill base much around surviv horror counterpart resid evil set comb apart counterpart overal style pace game unlik previou gam e much resid evil seri player inclin avoid battl enti reli disturb natur design sound slew enemi roam street includ back alley hidden car come interior explor ation enemi dot around corridor room spar enough maintai n feel isol fear game work heavili concept see make increasingli scare exampl would long dark corrid noth door explor player see end corridor creat fear someth end corridor make player move appreh nsive end possibl way describ combat silent hill compar e surviv horror game exampl surviv game resid evil walk c ...

# %%
# TF-IDF vektörizerı başlatıyoruz
vectorizer = TfidfVectorizer()

# TF-IDF matrisini oluşturuyoruz
#terim frekansları, belge frekanslarıni hesplar
#TF-IDF vektörlerine dönüştürür
tfidf_matrix = vectorizer.fit_transform(lemmatized_texts)

## Kelimeleri alalım
#F-IDF vektörleştirme işleminde kullanılan tüm kelimelerin essiz bir listesini döndürur
feature_names = vectorizer.get_feature_names_out()

# TF-IDF matrisini pandas DataFrame'e çevir-gorunurluk acisindan- calismasi kolay
tfidf_df = pd.DataFrame(tfidf_matrix.toarray(), columns=feature_names)

# İlk birkaç satırı gösterelim-ilk 5 cümle
print(tfidf_df.head())

#Her satır bir cümleyi temsil eder
#Her sütun bir kelimeyi temsil eder
#Hücreler ise o kelimenin o cümledeki TF-IDF skorudur - her cumle icin degisir-bakiniz:slaytlar
# Out:
#          ab    abando   abandon      abat      abil       abl   abolish  \
# 0  0.001814  0.001814  0.010887  0.001814  0.023588  0.012701  0.001814
#
#       abras  abruptli   absolut  ...       yer  yesterday       yet     yodel  \
# 0  0.003629  0.003629  0.001814  ...  0.007258   0.001814  0.005443  0.003629
#
#       young   younger    yramid    ysical       zip     zombi
# 0  0.003629  0.001814  0.001814  0.001814  0.001814  0.005443
#
# [1 rows x 3066 columns]

# %%
tfidf_df.to_csv('tfidf_stemmed.csv', index=False)
